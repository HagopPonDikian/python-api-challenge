# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        response = requests.get(city_url)    
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | turpan
# Processing Record 3 of Set 1 | ca mau
# Processing Record 4 of Set 1 | igarka
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | sinabang
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | nadi
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | blackmans bay
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | porto velho
# Processing Record 14 of Set 1 | stanley
# Processing Record 15 of Set 1 | wenling
# Processing Record 16 of Set 1 | chonchi
# Processing Record 17 of Set 1 | whitehorse
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | dera bugti
# Processing Record 21 of Set 1 | rikaze
# Processing Record 22 of Set 1 | cartagena del chaira
# Processing Record 23 of Set 1 | piacabucu
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | polyarnyy
# Processing Record 26 of Set 1 | praia da vitoria
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | bilibino
# Processing Record 29 of Set 1 | vilyuysk
# Processing Record 30 of Set 1 | st. john's
# Processing Record 31 of Set 1 | enterprise
# Processing Record 32 of Set 1 | choibalsan
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | cala rajada
# City not found. Skipping...
# Processing Record 35 of Set 1 | suva
# Processing Record 36 of Set 1 | xinyuan
# Processing Record 37 of Set 1 | cozumel
# Processing Record 38 of Set 1 | bel ombre
# Processing Record 39 of Set 1 | tazovsky
# Processing Record 40 of Set 1 | tura
# Processing Record 41 of Set 1 | edinburgh of the seven seas
# Processing Record 42 of Set 1 | badger
# Processing Record 43 of Set 1 | yuzhno-kurilsk
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | weno
# Processing Record 46 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | verkh-chebula
# Processing Record 50 of Set 1 | altamont
# Processing Record 0 of Set 2 | sona
# Processing Record 1 of Set 2 | wolbrom
# Processing Record 2 of Set 2 | mirontsi
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 5 of Set 2 | pasuquin
# Processing Record 6 of Set 2 | tsiombe
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | college
# Processing Record 11 of Set 2 | bonoua
# Processing Record 12 of Set 2 | labrador city
# Processing Record 13 of Set 2 | saipan
# Processing Record 14 of Set 2 | aswan
# Processing Record 15 of Set 2 | dalandzadgad
# Processing Record 16 of Set 2 | ta`u
# Processing Record 17 of Set 2 | brownwood
# Processing Record 18 of Set 2 | holstebro
# Processing Record 19 of Set 2 | ifrane
# Processing Record 20 of Set 2 | leticia
# Processing Record 21 of Set 2 | ancud
# Processing Record 22 of Set 2 | mount pearl
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | bayt kahil
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | revda
# Processing Record 27 of Set 2 | uturoa
# Processing Record 28 of Set 2 | chazuta
# Processing Record 29 of Set 2 | birjand
# Processing Record 30 of Set 2 | la passe
# Processing Record 31 of Set 2 | invercargill
# Processing Record 32 of Set 2 | wanaraja
# Processing Record 33 of Set 2 | port macquarie
# Processing Record 34 of Set 2 | flying fish cove
# Processing Record 35 of Set 2 | olonkinbyen
# Processing Record 36 of Set 2 | wynyard
# Processing Record 37 of Set 2 | preobrazheniye
# Processing Record 38 of Set 2 | dudinka
# Processing Record 39 of Set 2 | am timan
# Processing Record 40 of Set 2 | keflavik
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | sittwe
# Processing Record 43 of Set 2 | hauterive
# Processing Record 44 of Set 2 | hawaiian paradise park
# Processing Record 45 of Set 2 | margaret river
# Processing Record 46 of Set 2 | potosi
# Processing Record 47 of Set 2 | pozos de gamboa
# Processing Record 48 of Set 2 | udachny
# Processing Record 49 of Set 2 | okha
# Processing Record 0 of Set 3 | enewetak
# Processing Record 1 of Set 3 | fort st. john
# Processing Record 2 of Set 3 | masterton
# Processing Record 3 of Set 3 | al kharijah
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | shache
# Processing Record 6 of Set 3 | sinop
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | hinton
# Processing Record 11 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 12 of Set 3 | poli
# Processing Record 13 of Set 3 | minas de marcona
# Processing Record 14 of Set 3 | ortigueira
# Processing Record 15 of Set 3 | soure
# Processing Record 16 of Set 3 | vorkuta
# Processing Record 17 of Set 3 | la'ie
# Processing Record 18 of Set 3 | canutama
# Processing Record 19 of Set 3 | yamba
# Processing Record 20 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 21 of Set 3 | gafanha da nazare
# Processing Record 22 of Set 3 | roma
# Processing Record 23 of Set 3 | kinablangan
# Processing Record 24 of Set 3 | la ronge
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | port mathurin
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | kaiyuan
# Processing Record 30 of Set 3 | palmer
# Processing Record 31 of Set 3 | ballina
# Processing Record 32 of Set 3 | al jawf
# Processing Record 33 of Set 3 | kerikeri
# Processing Record 34 of Set 3 | zyryanovsk
# Processing Record 35 of Set 3 | luquillo
# Processing Record 36 of Set 3 | wailua homesteads
# Processing Record 37 of Set 3 | ust-nera
# Processing Record 38 of Set 3 | kapuskasing
# Processing Record 39 of Set 3 | astolfo dutra
# Processing Record 40 of Set 3 | trevelin
# Processing Record 41 of Set 3 | west island
# Processing Record 42 of Set 3 | east honolulu
# City not found. Skipping...
# Processing Record 43 of Set 3 | iskateley
# Processing Record 44 of Set 3 | sibul
# Processing Record 45 of Set 3 | port lincoln
# Processing Record 46 of Set 3 | papao
# Processing Record 47 of Set 3 | port augusta
# Processing Record 48 of Set 3 | thunder bay
# Processing Record 49 of Set 3 | papatowai
# Processing Record 0 of Set 4 | filey
# Processing Record 1 of Set 4 | sainte-suzanne
# Processing Record 2 of Set 4 | atafu village
# Processing Record 3 of Set 4 | harstad
# Processing Record 4 of Set 4 | aasiaat
# Processing Record 5 of Set 4 | inirida
# Processing Record 6 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | ponta delgada
# Processing Record 9 of Set 4 | isafjordur
# Processing Record 10 of Set 4 | remire-montjoly
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | fale old settlement
# Processing Record 13 of Set 4 | mount isa
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | misratah
# Processing Record 17 of Set 4 | cochin
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | jamestown
# Processing Record 20 of Set 4 | livingston
# Processing Record 21 of Set 4 | naze
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | klyuchi
# Processing Record 24 of Set 4 | yarmouth
# Processing Record 25 of Set 4 | kailua-kona
# Processing Record 26 of Set 4 | ternate
# Processing Record 27 of Set 4 | taulaga
# Processing Record 28 of Set 4 | coahuayana de hidalgo
# Processing Record 29 of Set 4 | auki
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | kuta
# Processing Record 32 of Set 4 | mandera
# Processing Record 33 of Set 4 | vadso
# Processing Record 34 of Set 4 | boguchany
# Processing Record 35 of Set 4 | ad dabbah
# Processing Record 36 of Set 4 | kaindy
# Processing Record 37 of Set 4 | siwa oasis
# Processing Record 38 of Set 4 | maholi
# Processing Record 39 of Set 4 | ungsang-nodongjagu
# Processing Record 40 of Set 4 | yukhnov
# Processing Record 41 of Set 4 | rio gallegos
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | yaren
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | myory
# Processing Record 48 of Set 4 | laoag
# Processing Record 49 of Set 4 | susuman
# Processing Record 0 of Set 5 | sitka
# Processing Record 1 of Set 5 | mitsamiouli
# Processing Record 2 of Set 5 | sabang
# Processing Record 3 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 4 of Set 5 | alta
# Processing Record 5 of Set 5 | san antonio de pale
# Processing Record 6 of Set 5 | fisterra
# Processing Record 7 of Set 5 | morehead city
# Processing Record 8 of Set 5 | piti village
# Processing Record 9 of Set 5 | mejit
# Processing Record 10 of Set 5 | laojunmiao
# Processing Record 11 of Set 5 | talcahuano
# Processing Record 12 of Set 5 | tenenkou
# Processing Record 13 of Set 5 | khandyga
# Processing Record 14 of Set 5 | zhangye
# Processing Record 15 of Set 5 | menongue
# Processing Record 16 of Set 5 | hermanus
# Processing Record 17 of Set 5 | castillos
# Processing Record 18 of Set 5 | anadyr
# Processing Record 19 of Set 5 | kupang
# Processing Record 20 of Set 5 | vershino-darasunskiy
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | vrangel'
# Processing Record 23 of Set 5 | az zahiriyah
# Processing Record 24 of Set 5 | shakawe
# Processing Record 25 of Set 5 | port alfred
# Processing Record 26 of Set 5 | kuragino
# Processing Record 27 of Set 5 | nogliki
# Processing Record 28 of Set 5 | deder
# Processing Record 29 of Set 5 | fonte boa
# Processing Record 30 of Set 5 | bogatoye
# Processing Record 31 of Set 5 | ashland
# Processing Record 32 of Set 5 | lusambo
# Processing Record 33 of Set 5 | cestos city
# Processing Record 34 of Set 5 | peace river
# Processing Record 35 of Set 5 | sardarshahr
# Processing Record 36 of Set 5 | douentza
# Processing Record 37 of Set 5 | pallasovka
# Processing Record 38 of Set 5 | ilha de mocambique
# Processing Record 39 of Set 5 | khovd
# Processing Record 40 of Set 5 | tughyl
# Processing Record 41 of Set 5 | montego bay
# Processing Record 42 of Set 5 | pervomaysk
# Processing Record 43 of Set 5 | illizi
# Processing Record 44 of Set 5 | ciudad lazaro cardenas
# Processing Record 45 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 5 | rotenburg
# Processing Record 47 of Set 5 | eraan
# Processing Record 48 of Set 5 | dalbandin
# Processing Record 49 of Set 5 | kolonia
# Processing Record 0 of Set 6 | havran
# Processing Record 1 of Set 6 | utrik
# Processing Record 2 of Set 6 | ba
# City not found. Skipping...
# Processing Record 3 of Set 6 | rio turbio
# City not found. Skipping...
# Processing Record 4 of Set 6 | garachico
# Processing Record 5 of Set 6 | kuala belait
# Processing Record 6 of Set 6 | nova sintra
# Processing Record 7 of Set 6 | shenzhen
# Processing Record 8 of Set 6 | wajir
# Processing Record 9 of Set 6 | puerto rico
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | akureyri
# Processing Record 12 of Set 6 | luganville
# Processing Record 13 of Set 6 | hopelchen
# Processing Record 14 of Set 6 | fort bragg
# Processing Record 15 of Set 6 | christchurch
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | mirnyy
# Processing Record 18 of Set 6 | saudarkrokur
# Processing Record 19 of Set 6 | shalqar
# Processing Record 20 of Set 6 | plettenberg bay
# Processing Record 21 of Set 6 | dzilam gonzalez
# Processing Record 22 of Set 6 | bondo
# Processing Record 23 of Set 6 | anloga
# Processing Record 24 of Set 6 | haiku-pauwela
# Processing Record 25 of Set 6 | sidney
# Processing Record 26 of Set 6 | tarakan
# Processing Record 27 of Set 6 | qaqortoq
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | kirensk
# Processing Record 30 of Set 6 | lihue
# Processing Record 31 of Set 6 | ji parana
# City not found. Skipping...
# Processing Record 32 of Set 6 | hastings
# Processing Record 33 of Set 6 | agua prieta
# Processing Record 34 of Set 6 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 35 of Set 6 | loreto
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | kapa'a
# Processing Record 38 of Set 6 | rabaul
# Processing Record 39 of Set 6 | al bayda
# Processing Record 40 of Set 6 | moroto
# Processing Record 41 of Set 6 | nouadhibou
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | sumbawa besar
# Processing Record 44 of Set 6 | puerto palomas
# Processing Record 45 of Set 6 | mhamid
# Processing Record 46 of Set 6 | asau village
# City not found. Skipping...
# Processing Record 47 of Set 6 | kiunga
# Processing Record 48 of Set 6 | cheria
# Processing Record 49 of Set 6 | katsuura
# Processing Record 0 of Set 7 | holualoa
# Processing Record 1 of Set 7 | yallahs
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | magadan
# Processing Record 4 of Set 7 | dabakala
# Processing Record 5 of Set 7 | rouissat
# Processing Record 6 of Set 7 | crescent city
# Processing Record 7 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 8 of Set 7 | victorica
# Processing Record 9 of Set 7 | nyala
# Processing Record 10 of Set 7 | manado
# Processing Record 11 of Set 7 | pamandzi
# Processing Record 12 of Set 7 | vilyuchinsk
# Processing Record 13 of Set 7 | avarua
# Processing Record 14 of Set 7 | maputo
# Processing Record 15 of Set 7 | yung shue wan
# Processing Record 16 of Set 7 | vernon
# Processing Record 17 of Set 7 | bodo
# Processing Record 18 of Set 7 | lingyuan
# Processing Record 19 of Set 7 | kavalerovo
# Processing Record 20 of Set 7 | pangkalanbuun
# Processing Record 21 of Set 7 | tommot
# Processing Record 22 of Set 7 | bikenibeu village
# Processing Record 23 of Set 7 | nuuk
# Processing Record 24 of Set 7 | beichengqu
# Processing Record 25 of Set 7 | novyy urgal
# Processing Record 26 of Set 7 | lingig
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | fada
# Processing Record 30 of Set 7 | amga
# Processing Record 31 of Set 7 | howrah
# Processing Record 32 of Set 7 | tulun
# Processing Record 33 of Set 7 | cascais
# Processing Record 34 of Set 7 | daru
# Processing Record 35 of Set 7 | arno
# Processing Record 36 of Set 7 | langsa
# Processing Record 37 of Set 7 | dwarka
# Processing Record 38 of Set 7 | tela
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | kokofata
# City not found. Skipping...
# Processing Record 41 of Set 7 | lebu
# Processing Record 42 of Set 7 | agnita
# Processing Record 43 of Set 7 | llerena
# Processing Record 44 of Set 7 | constantia
# Processing Record 45 of Set 7 | burang
# Processing Record 46 of Set 7 | horta
# Processing Record 47 of Set 7 | leh
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | rodekro
# Processing Record 0 of Set 8 | koundara
# Processing Record 1 of Set 8 | hexham
# Processing Record 2 of Set 8 | shilin
# Processing Record 3 of Set 8 | schwerte
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 8 | sao joao da barra
# Processing Record 7 of Set 8 | huilong
# Processing Record 8 of Set 8 | lucheng
# Processing Record 9 of Set 8 | tangalle
# Processing Record 10 of Set 8 | nizhneudinsk
# Processing Record 11 of Set 8 | saint-pierre
# Processing Record 12 of Set 8 | baskale
# Processing Record 13 of Set 8 | malvan
# Processing Record 14 of Set 8 | guasave
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | rupert
# Processing Record 17 of Set 8 | chibougamau
# Processing Record 18 of Set 8 | waimea
# Processing Record 19 of Set 8 | shanwei
# Processing Record 20 of Set 8 | qamdo
# Processing Record 21 of Set 8 | rongelap
# Processing Record 22 of Set 8 | prince rupert
# Processing Record 23 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 24 of Set 8 | verkhneural'sk
# Processing Record 25 of Set 8 | priargunsk
# Processing Record 26 of Set 8 | island harbour
# Processing Record 27 of Set 8 | nikolayevsk-on-amure
# Processing Record 28 of Set 8 | sisimiut
# Processing Record 29 of Set 8 | vorgashor
# Processing Record 30 of Set 8 | ko pha ngan
# Processing Record 31 of Set 8 | oranjemund
# Processing Record 32 of Set 8 | luderitz
# Processing Record 33 of Set 8 | russas
# Processing Record 34 of Set 8 | malakanagiri
# Processing Record 35 of Set 8 | lazaro cardenas
# Processing Record 36 of Set 8 | jayapura
# Processing Record 37 of Set 8 | yokadouma
# Processing Record 38 of Set 8 | fort-shevchenko
# Processing Record 39 of Set 8 | munstertal/schwarzwald
# City not found. Skipping...
# Processing Record 40 of Set 8 | toliara
# Processing Record 41 of Set 8 | turgen
# Processing Record 42 of Set 8 | suntar
# Processing Record 43 of Set 8 | pacific grove
# Processing Record 44 of Set 8 | kashgar
# Processing Record 45 of Set 8 | hammerfest
# Processing Record 46 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 47 of Set 8 | tshikapa
# Processing Record 48 of Set 8 | dunedin
# Processing Record 49 of Set 8 | porto novo
# Processing Record 0 of Set 9 | san carlos centro
# Processing Record 1 of Set 9 | sao jose da coroa grande
# Processing Record 2 of Set 9 | tofol
# Processing Record 3 of Set 9 | ruma
# Processing Record 4 of Set 9 | villa gesell
# Processing Record 5 of Set 9 | inderbor
# Processing Record 6 of Set 9 | betio village
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | arkhangel'sk
# Processing Record 9 of Set 9 | berwick-upon-tweed
# Processing Record 10 of Set 9 | aldan
# Processing Record 11 of Set 9 | dongola
# Processing Record 12 of Set 9 | smithers
# Processing Record 13 of Set 9 | leer
# Processing Record 14 of Set 9 | alenquer
# Processing Record 15 of Set 9 | alo
# Processing Record 16 of Set 9 | international falls
# Processing Record 17 of Set 9 | flin flon
# Processing Record 18 of Set 9 | lensk
# Processing Record 19 of Set 9 | riachao das neves
# Processing Record 20 of Set 9 | antonio enes
# Processing Record 21 of Set 9 | margate
# Processing Record 22 of Set 9 | altinyayla
# Processing Record 23 of Set 9 | turkmenbasy
# Processing Record 24 of Set 9 | kaoma
# Processing Record 25 of Set 9 | cairns city
# City not found. Skipping...
# Processing Record 26 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 27 of Set 9 | shingu
# Processing Record 28 of Set 9 | hennenman
# Processing Record 29 of Set 9 | jinchang
# Processing Record 30 of Set 9 | newman
# Processing Record 31 of Set 9 | chiknayakanhalli
# Processing Record 32 of Set 9 | dalby
# Processing Record 33 of Set 9 | massawa
# Processing Record 34 of Set 9 | aitape
# Processing Record 35 of Set 9 | lodja
# Processing Record 36 of Set 9 | hassi messaoud
# Processing Record 37 of Set 9 | hadibu
# Processing Record 38 of Set 9 | pacasmayo
# Processing Record 39 of Set 9 | fellsmere
# Processing Record 40 of Set 9 | kudahuvadhoo
# Processing Record 41 of Set 9 | zeya
# Processing Record 42 of Set 9 | patacamaya
# Processing Record 43 of Set 9 | makokou
# Processing Record 44 of Set 9 | reggane
# Processing Record 45 of Set 9 | mahina
# Processing Record 46 of Set 9 | malvik
# Processing Record 47 of Set 9 | east london
# Processing Record 48 of Set 9 | belleville
# Processing Record 49 of Set 9 | salinopolis
# Processing Record 0 of Set 10 | levuka
# Processing Record 1 of Set 10 | parkano
# Processing Record 2 of Set 10 | colonia
# Processing Record 3 of Set 10 | rio grande
# Processing Record 4 of Set 10 | vikhorevka
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | labytnangi
# Processing Record 7 of Set 10 | argo
# Processing Record 8 of Set 10 | mersa matruh
# Processing Record 9 of Set 10 | tamanrasset
# Processing Record 10 of Set 10 | dazhou
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | kolonia town
# Processing Record 13 of Set 10 | ketchikan
# Processing Record 14 of Set 10 | nushki
# Processing Record 15 of Set 10 | bamboo flat
# Processing Record 16 of Set 10 | paracuru
# Processing Record 17 of Set 10 | conduaga
# Processing Record 18 of Set 10 | kamyzyak
# Processing Record 19 of Set 10 | mazeikiai
# Processing Record 20 of Set 10 | nelson bay
# Processing Record 21 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 22 of Set 10 | yelizovo
# Processing Record 23 of Set 10 | lospalos
# Processing Record 24 of Set 10 | tadine
# Processing Record 25 of Set 10 | labruguiere
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | geraldton
# Processing Record 28 of Set 10 | samana
# Processing Record 29 of Set 10 | zagora
# Processing Record 30 of Set 10 | sretensk
# Processing Record 31 of Set 10 | weihai
# Processing Record 32 of Set 10 | karratha
# Processing Record 33 of Set 10 | santa elena de uairen
# Processing Record 34 of Set 10 | urangan
# Processing Record 35 of Set 10 | tikaitnagar
# Processing Record 36 of Set 10 | verkhnevilyuysk
# Processing Record 37 of Set 10 | fuyu
# Processing Record 38 of Set 10 | tres arroyos
# Processing Record 39 of Set 10 | lorengau
# Processing Record 40 of Set 10 | stettler
# Processing Record 41 of Set 10 | tabou
# Processing Record 42 of Set 10 | constitucion
# Processing Record 43 of Set 10 | sultanah
# Processing Record 44 of Set 10 | abraham's bay
# City not found. Skipping...
# Processing Record 45 of Set 10 | hun
# Processing Record 46 of Set 10 | puerto baquerizo moreno
# Processing Record 47 of Set 10 | nar'yan-mar
# Processing Record 48 of Set 10 | cumbal
# Processing Record 49 of Set 10 | gorodishche
# Processing Record 0 of Set 11 | el nido
# Processing Record 1 of Set 11 | uruzgan
# Processing Record 2 of Set 11 | as sulayyil
# Processing Record 3 of Set 11 | pierre
# Processing Record 4 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | poplar grove
# Processing Record 7 of Set 11 | pankrushikha
# Processing Record 8 of Set 11 | isfahan
# Processing Record 9 of Set 11 | dihok
# Processing Record 10 of Set 11 | broken hill
# Processing Record 11 of Set 11 | afif
# Processing Record 12 of Set 11 | namtsy
# Processing Record 13 of Set 11 | uttarkashi
# Processing Record 14 of Set 11 | santiago
# Processing Record 15 of Set 11 | omutinskiy
# Processing Record 16 of Set 11 | guymon
# Processing Record 17 of Set 11 | andkhoy
# Processing Record 18 of Set 11 | tshabong
# Processing Record 19 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 20 of Set 11 | chui
# Processing Record 21 of Set 11 | mammoth lakes
# Processing Record 22 of Set 11 | walvis bay
# Processing Record 23 of Set 11 | sirjan
# Processing Record 24 of Set 11 | maceio
# Processing Record 25 of Set 11 | florida ridge
# Processing Record 26 of Set 11 | adh dhayd
# Processing Record 27 of Set 11 | sala
# Processing Record 28 of Set 11 | grinnell
# Processing Record 29 of Set 11 | nova vicosa
# Processing Record 30 of Set 11 | aur
# Processing Record 31 of Set 11 | aver-o-mar
# Processing Record 32 of Set 11 | homosassa springs
# Processing Record 33 of Set 11 | cannonvale
# Processing Record 34 of Set 11 | poronaysk
# Processing Record 35 of Set 11 | mogadishu
# Processing Record 36 of Set 11 | tralee
# Processing Record 37 of Set 11 | sal rei
# Processing Record 38 of Set 11 | yola
# Processing Record 39 of Set 11 | klamath falls
# Processing Record 40 of Set 11 | mayna
# Processing Record 41 of Set 11 | antofagasta
# Processing Record 42 of Set 11 | skeldon
# Processing Record 43 of Set 11 | ath thawrah
# Processing Record 44 of Set 11 | bethanie
# Processing Record 45 of Set 11 | jutai
# Processing Record 46 of Set 11 | mildura
# Processing Record 47 of Set 11 | hohhot
# Processing Record 48 of Set 11 | cabedelo
# Processing Record 49 of Set 11 | banda aceh
# Processing Record 0 of Set 12 | leava
# Processing Record 1 of Set 12 | phan rang-thap cham
# Processing Record 2 of Set 12 | santo antonio
# Processing Record 3 of Set 12 | midvagur
# Processing Record 4 of Set 12 | kasane
# Processing Record 5 of Set 12 | jamai
# Processing Record 6 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 7 of Set 12 | avellaneda
# Processing Record 8 of Set 12 | nabire
# Processing Record 9 of Set 12 | oltinko'l
# Processing Record 10 of Set 12 | zhosaly
# Processing Record 11 of Set 12 | okeechobee
# Processing Record 12 of Set 12 | alto araguaia
# Processing Record 13 of Set 12 | mabamba
# Processing Record 14 of Set 12 | torpoint
# Processing Record 15 of Set 12 | lashio
# Processing Record 16 of Set 12 | we
# City not found. Skipping...
# Processing Record 17 of Set 12 | crane
# Processing Record 18 of Set 12 | upata
# Processing Record 19 of Set 12 | alexandria
# Processing Record 20 of Set 12 | lerwick
# Processing Record 21 of Set 12 | houlton
# Processing Record 22 of Set 12 | meadow lakes
# Processing Record 23 of Set 12 | pokaran
# Processing Record 24 of Set 12 | jeju city
# Processing Record 25 of Set 12 | cartagena
# Processing Record 26 of Set 12 | vernal
# Processing Record 27 of Set 12 | hobyo
# Processing Record 28 of Set 12 | berezovyy
# Processing Record 29 of Set 12 | naryn
# Processing Record 30 of Set 12 | howard springs
# Processing Record 31 of Set 12 | conceicao da barra
# Processing Record 32 of Set 12 | maine soroa
# Processing Record 33 of Set 12 | lethem
# Processing Record 34 of Set 12 | ulladulla
# Processing Record 35 of Set 12 | kunduz
# Processing Record 36 of Set 12 | wankyi
# Processing Record 37 of Set 12 | taltal
# Processing Record 38 of Set 12 | lamu
# Processing Record 39 of Set 12 | alvaraes
# Processing Record 40 of Set 12 | yambio
# Processing Record 41 of Set 12 | coron
# Processing Record 42 of Set 12 | vila velha
# Processing Record 43 of Set 12 | chulym
# Processing Record 44 of Set 12 | yoloten
# Processing Record 45 of Set 12 | baykal'sk
# Processing Record 46 of Set 12 | voranava
# Processing Record 47 of Set 12 | vredendal
# Processing Record 48 of Set 12 | shenkursk
# Processing Record 49 of Set 12 | luebo
# Processing Record 0 of Set 13 | baissa
# Processing Record 1 of Set 13 | el calafate
# Processing Record 2 of Set 13 | ajdabiya
# Processing Record 3 of Set 13 | tuy hoa
# Processing Record 4 of Set 13 | nuku'alofa
# Processing Record 5 of Set 13 | pimentel
# Processing Record 6 of Set 13 | kampung tanjung karang
# Processing Record 7 of Set 13 | borogontsy
# Processing Record 8 of Set 13 | campofelice di roccella
# Processing Record 9 of Set 13 | cuyo
# Processing Record 10 of Set 13 | boca suno
# Processing Record 11 of Set 13 | happy valley-goose bay
# Processing Record 12 of Set 13 | nueva gerona
# Processing Record 13 of Set 13 | glendive
# Processing Record 14 of Set 13 | ivybridge
# Processing Record 15 of Set 13 | maardu
# Processing Record 16 of Set 13 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df["Max Temp"] = city_data_df["Max Temp"] - 273 # changing to value to Celsius
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     grytviken -54.2811  -36.5092      6.00        85          18
# 1        turpan  42.9333   89.1667     15.90        26           0
# 2        ca mau   9.1769  105.1500     26.35        88         100
# 3        igarka  67.4667   86.5833      6.76        98         100
# 4  puerto ayora  -0.7393  -90.3518     23.79        96         100
#
#    Wind Speed Country        Date
# 0        4.64      GS  1697720872
# 1        0.76      CN  1697720872
# 2        1.48      VN  1697720873
# 3        5.39      RU  1697720873
# 4        2.24      EC  1697720651

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           grytviken -54.2811  -36.5092      6.00        85          18
# 1              turpan  42.9333   89.1667     15.90        26           0
# 2              ca mau   9.1769  105.1500     26.35        88         100
# 3              igarka  67.4667   86.5833      6.76        98         100
# 4        puerto ayora  -0.7393  -90.3518     23.79        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.64      GS  1697720872
# 1              0.76      CN  1697720872
# 2              1.48      VN  1697720873
# 3              5.39      RU  1697720873
# 4              2.24      EC  1697720651

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x="Lat", y="Max Temp", s=35, alpha=0.8, edgecolor='black', marker='o', title="City Latitude vs. Temperature")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x="Lat", y="Humidity", s=35, alpha=0.8, edgecolor='black', marker='o', title="City Latitude vs. Humidity")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Cloudiness", s=35, alpha=0.8, edgecolor='black', marker='o', title="City Latitude vs. Cloudiness")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x="Lat", y="Wind Speed", s=35, alpha=0.8, edgecolor='black', marker='o', title="City Latitude vs. Wind Speed")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y, x_label, y_label):
    
    slope, intercept = np.polyfit(x, y, 1)
    trendline = slope * x + intercept
    r = np.corrcoef(x, y)[0, 1]
    
    print(f"the r-value is:{r}")

    plt.scatter(x, y, label="Data", color="blue")
    
    
    # Create a line plot for the linear trendline
    plt.plot(x, trendline, label="Linear Regression", color="red")
    # Customize the plot with labels and a title
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Show the legend

    # Display the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                turpan  42.9333   89.1667     15.90        26           0
# 2                ca mau   9.1769  105.1500     26.35        88         100
# 3                igarka  67.4667   86.5833      6.76        98         100
# 5              sinabang   2.4803   96.3801     26.55        83         100
# 6        ribeira grande  38.5167  -28.7000     20.37        64          20
#
#          Wind Speed Country        Date
# City_ID
# 1              0.76      CN  1697720872
# 2              1.48      VN  1697720873
# 3              5.39      RU  1697720873
# 5              1.39      ID  1697720873
# 6              5.81      PT  1697720873

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            grytviken -54.2811  -36.5092      6.00        85          18
# 4         puerto ayora  -0.7393  -90.3518     23.79        96         100
# 7                 nadi -17.8000  177.4167     24.15        83          20
# 9             waitangi -43.9535 -176.5597     11.77        82          77
# 10       blackmans bay -43.0167  147.3167     11.67        86          96
#
#          Wind Speed Country        Date
# City_ID
# 0              4.64      GS  1697720872
# 4              2.24      EC  1697720651
# 7              2.06      FJ  1697720873
# 9              9.32      NZ  1697720873
# 10             0.81      AU  1697720874

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"], "Latitude", "Max Temp")
# Out:
# the r-value is:-0.82656622053085

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"], "Latitude", "Max Temp")
# Out:
# the r-value is:0.7643318900146222

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# the r-value is:0.159917312772545

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Humidity"], "Latitude", "Humidity")
# Out:
# the r-value is:0.02448721904742107

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# the r-value is:0.10850987704183775

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness")
# Out:
# the r-value is:0.1066113001077482

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere 
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# the r-value is:0.20911219686526578

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed")
# Out:
# the r-value is:-0.21480095960298312

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
